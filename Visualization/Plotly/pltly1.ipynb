# %%
# %pip install --upgrade nbformat==4.2.0 ipykernel
# Out:
# Requirement already satisfied: nbformat==4.2.0 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (4.2.0)
# Requirement already satisfied: ipykernel in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (7.3.0)
# Requirement already satisfied: ipython-genutils in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from nbformat==4.2.0) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from nbformat==4.2.0) (4.26.0)
# Requirement already satisfied: jupyter-core in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from nbformat==4.2.0) (5.9.1)
# Requirement already satisfied: traitlets>=4.1 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from nbformat==4.2.0) (5.15.1)
# Requirement already satisfied: appnope>=0.1.2 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipykernel) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipykernel) (9.15.0)
# Requirement already satisfied: jupyter-client>=8.9.0 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipykernel) (8.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: nest-asyncio2>=1.7.0 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipykernel) (1.7.2)
# Requirement already satisfied: packaging>=22 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipykernel) (26.2)
# Requirement already satisfied: psutil>=5.7 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipykernel) (6.5.7)
# Requirement already satisfied: decorator>=5.1.0 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (0.20.0)
# Requirement already satisfied: pexpect>4.6 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel) (0.8.7)
# Requirement already satisfied: attrs>=22.2.0 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==4.2.0) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==4.2.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==4.2.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==4.2.0) (2026.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from jupyter-client>=8.9.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=4.13.0 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from jupyter-client>=8.9.0->ipykernel) (4.16.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from jupyter-core->nbformat==4.2.0) (4.11.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.9.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.2)
# Requirement already satisfied: pure-eval in /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import plotly as py
import seaborn as sns
import plotly.express as px
import plotly.io as pio

# %matplotlib inline

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
pd.options.plotting.backend = "plotly"
pio.renderers.default = "vscode"
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-4.0.0.min"</script>

# %% [markdown]
# # Basics

# %%
arr_1 = np.random.randn(50,4)
df_1 = pd.DataFrame(arr_1, columns=['A','B','C','D'])
df_1.head()
df_1.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'variable=A<br>index=%{x}<br>value=%{y}<extra></extra>',
#               'legendgroup': 'A',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines',
#               'name': 'A',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': {'bdata': 'AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGBkaGxwdHh8gISIjJCUmJygpKissLS4vMDE=', 'dtype': 'i1'},
#               'xaxis': 'x',
#               'y': {'bdata': ('wVfQScKTuL+i1uCKSijbP4l1UdNieu' ... 'hNP90/BShUqQVa+D9kPgPMnePSPw=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'hovertemplate': 'variable=B<br>index=%{x}<br>value=%{y}<extra></extra>',
#               'legendgroup': 'B',
#               'line': {'color': '#EF553B', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines',
#               'name': 'B',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': {'bdata': 'AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGBkaGxwdHh8gISIjJCUmJygpKissLS4vMDE=', 'dtype': 'i1'},
#               'xaxis': 'x',
#               'y': {'bdata': ('4jHGdCHe1L/4Y0/SiUvVv2LQHBT6AP' ... 'CTWMm/68PHNvra2L/Q1Dph/X73Pw=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'hovertemplate': 'variable=C<br>index=%{x}<br>value=%{y}<extra></extra>',
#               'legendgroup': 'C',
#               'line': {'color': '#00cc96', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines',
#               'name': 'C',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': {'bdata': 'AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGBkaGxwdHh8gISIjJCUmJygpKissLS4vMDE=', 'dtype': 'i1'},
#               'xaxis': 'x',
#               'y': {'bdata': ('jw6kHXmPtr++RFGimNzmP9WMghltr+' ... 'RiW/S/kigba+hV1b+Pdc57UkiePw=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'hovertemplate': 'variable=D<br>index=%{x}<br>value=%{y}<extra></extra>',
#               'legendgroup': 'D',
#               'line': {'color': '#ab63fa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines',
#               'name': 'D',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': {'bdata': 'AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGBkaGxwdHh8gISIjJCUmJygpKissLS4vMDE=', 'dtype': 'i1'},
#               'xaxis': 'x',
#               'y': {'bdata': ('XWhrkEkS9z86oDSUyAW/v69erZF3U/' ... 'Ahm8W/B+J2BK0R4b8SgL1yNFTQvw=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'variable'}, 'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'index'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'value'}}}
# })

# %% [markdown]
# # Line Plots

# %%
import plotly.graph_objects as go
df_stocks = px.data.stocks()

px.line(df_stocks,x='date',y='GOOG',labels={'x':'Date','y':'Price'})

px.line(df_stocks,x='date',y=['GOOG','AAPL'],labels={'x':'Date','y':'Price'}, title='Apple vs Google')

fig = go.Figure()
fig.add_trace(go.Scatter(x=df_stocks.date,y=df_stocks.AAPL,mode='lines',name='Apple'))
fig.add_trace(go.Scatter(x=df_stocks.date,y=df_stocks.AMZN,mode='lines+markers',name='Amazon'))
fig.add_trace(go.Scatter(x=df_stocks.date,y=df_stocks.GOOG,mode='lines+markers',name='Google',line=dict(color='firebrick',width=2,dash='dashdot')))

fig.update_layout(
    title='Stock Price Data 2018 - 2020',
    showlegend=True, 
    margin=dict(l=100, r=20, t=110), 
    xaxis=dict(
        showline=True, 
        showgrid=False, 
        showticklabels=True, 
        linecolor='rgb(204,204,204)',
        linewidth=2,
        ticks='outside',
        tickfont=dict(family='Arial', size=12, color='rgb(82,82,82)')
    ),
    yaxis=dict(
        showgrid=False, 
        zeroline=False, 
        showline=False,
        automargin=False 
    )
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'mode': 'lines',
#               'name': 'Apple',
#               'type': 'scatter',
#               'x': array(['2018-01-01', '2018-01-08', '2018-01-15', '2018-01-22', '2018-01-29',
#                           '2018-02-05', '2018-02-12', '2018-02-19', '2018-02-26', '2018-03-05',
#                           '2018-03-12', '2018-03-19', '2018-03-26', '2018-04-02', '2018-04-09',
#                           '2018-04-16', '2018-04-23', '2018-04-30', '2018-05-07', '2018-05-14',
#                           '2018-05-21', '2018-05-28', '2018-06-04', '2018-06-11', '2018-06-18',
#                           '2018-06-25', '2018-07-02', '2018-07-09', '2018-07-16', '2018-07-23',
#                           '2018-07-30', '2018-08-06', '2018-08-13', '2018-08-20', '2018-08-27',
#                           '2018-09-03', '2018-09-10', '2018-09-17', '2018-09-24', '2018-10-01',
#                           '2018-10-08', '2018-10-15', '2018-10-22', '2018-10-29', '2018-11-05',
#                           '2018-11-12', '2018-11-19', '2018-11-26', '2018-12-03', '2018-12-10',
#                           '2018-12-17', '2018-12-24', '2018-12-31', '2019-01-07', '2019-01-14',
#                           '2019-01-21', '2019-01-28', '2019-02-04', '2019-02-11', '2019-02-18',
#                           '2019-02-25', '2019-03-04', '2019-03-11', '2019-03-18', '2019-03-25',
#                           '2019-04-01', '2019-04-08', '2019-04-15', '2019-04-22', '2019-04-29',
#                           '2019-05-06', '2019-05-13', '2019-05-20', '2019-05-27', '2019-06-03',
#                           '2019-06-10', '2019-06-17', '2019-06-24', '2019-07-01', '2019-07-08',
#                           '2019-07-15', '2019-07-22', '2019-07-29', '2019-08-05', '2019-08-12',
#                           '2019-08-19', '2019-08-26', '2019-09-02', '2019-09-09', '2019-09-16',
#                           '2019-09-23', '2019-09-30', '2019-10-07', '2019-10-14', '2019-10-21',
#                           '2019-10-28', '2019-11-04', '2019-11-11', '2019-11-18', '2019-11-25',
#                           '2019-12-02', '2019-12-09', '2019-12-16', '2019-12-23', '2019-12-30'],
#                          dtype=object),
#               'y': {'bdata': ('AAAAAAAA8D/q2yr46jDwP+aHLuP7UP' ... 'k1K36M+T+Rn7rI+X76P2Lp9n0W2fo/'),
#                     'dtype': 'f8'}},
#              {'mode': 'lines+markers',
#               'name': 'Amazon',
#               'type': 'scatter',
#               'x': array(['2018-01-01', '2018-01-08', '2018-01-15', '2018-01-22', '2018-01-29',
#                           '2018-02-05', '2018-02-12', '2018-02-19', '2018-02-26', '2018-03-05',
#                           '2018-03-12', '2018-03-19', '2018-03-26', '2018-04-02', '2018-04-09',
#                           '2018-04-16', '2018-04-23', '2018-04-30', '2018-05-07', '2018-05-14',
#                           '2018-05-21', '2018-05-28', '2018-06-04', '2018-06-11', '2018-06-18',
#                           '2018-06-25', '2018-07-02', '2018-07-09', '2018-07-16', '2018-07-23',
#                           '2018-07-30', '2018-08-06', '2018-08-13', '2018-08-20', '2018-08-27',
#                           '2018-09-03', '2018-09-10', '2018-09-17', '2018-09-24', '2018-10-01',
#                           '2018-10-08', '2018-10-15', '2018-10-22', '2018-10-29', '2018-11-05',
#                           '2018-11-12', '2018-11-19', '2018-11-26', '2018-12-03', '2018-12-10',
#                           '2018-12-17', '2018-12-24', '2018-12-31', '2019-01-07', '2019-01-14',
#                           '2019-01-21', '2019-01-28', '2019-02-04', '2019-02-11', '2019-02-18',
#                           '2019-02-25', '2019-03-04', '2019-03-11', '2019-03-18', '2019-03-25',
#                           '2019-04-01', '2019-04-08', '2019-04-15', '2019-04-22', '2019-04-29',
#                           '2019-05-06', '2019-05-13', '2019-05-20', '2019-05-27', '2019-06-03',
#                           '2019-06-10', '2019-06-17', '2019-06-24', '2019-07-01', '2019-07-08',
#                           '2019-07-15', '2019-07-22', '2019-07-29', '2019-08-05', '2019-08-12',
#                           '2019-08-19', '2019-08-26', '2019-09-02', '2019-09-09', '2019-09-16',
#                           '2019-09-23', '2019-09-30', '2019-10-07', '2019-10-14', '2019-10-21',
#                           '2019-10-28', '2019-11-04', '2019-11-11', '2019-11-18', '2019-11-25',
#                           '2019-12-02', '2019-12-09', '2019-12-16', '2019-12-23', '2019-12-30'],
#                          dtype=object),
#               'y': {'bdata': ('AAAAAAAA8D/BgjiGdv3wP3v2rqIS2v' ... 'cbSVpB9z/NDaBU8Vb4P9qWWT7DDfg/'),
#                     'dtype': 'f8'}},
#              {'line': {'color': 'firebrick', 'dash': 'dashdot', 'width': 2},
#               'mode': 'lines+markers',
#               'name': 'Google',
#               'type': 'scatter',
#               'x': array(['2018-01-01', '2018-01-08', '2018-01-15', '2018-01-22', '2018-01-29',
#                           '2018-02-05', '2018-02-12', '2018-02-19', '2018-02-26', '2018-03-05',
#                           '2018-03-12', '2018-03-19', '2018-03-26', '2018-04-02', '2018-04-09',
#                           '2018-04-16', '2018-04-23', '2018-04-30', '2018-05-07', '2018-05-14',
#                           '2018-05-21', '2018-05-28', '2018-06-04', '2018-06-11', '2018-06-18',
#                           '2018-06-25', '2018-07-02', '2018-07-09', '2018-07-16', '2018-07-23',
#                           '2018-07-30', '2018-08-06', '2018-08-13', '2018-08-20', '2018-08-27',
#                           '2018-09-03', '2018-09-10', '2018-09-17', '2018-09-24', '2018-10-01',
#                           '2018-10-08', '2018-10-15', '2018-10-22', '2018-10-29', '2018-11-05',
#                           '2018-11-12', '2018-11-19', '2018-11-26', '2018-12-03', '2018-12-10',
#                           '2018-12-17', '2018-12-24', '2018-12-31', '2019-01-07', '2019-01-14',
#                           '2019-01-21', '2019-01-28', '2019-02-04', '2019-02-11', '2019-02-18',
#                           '2019-02-25', '2019-03-04', '2019-03-11', '2019-03-18', '2019-03-25',
#                           '2019-04-01', '2019-04-08', '2019-04-15', '2019-04-22', '2019-04-29',
#                           '2019-05-06', '2019-05-13', '2019-05-20', '2019-05-27', '2019-06-03',
#                           '2019-06-10', '2019-06-17', '2019-06-24', '2019-07-01', '2019-07-08',
#                           '2019-07-15', '2019-07-22', '2019-07-29', '2019-08-05', '2019-08-12',
#                           '2019-08-19', '2019-08-26', '2019-09-02', '2019-09-09', '2019-09-16',
#                           '2019-09-23', '2019-09-30', '2019-10-07', '2019-10-14', '2019-10-21',
#                           '2019-10-28', '2019-11-04', '2019-11-11', '2019-11-18', '2019-11-25',
#                           '2019-12-02', '2019-12-09', '2019-12-16', '2019-12-23', '2019-12-30'],
#                          dtype=object),
#               'y': {'bdata': ('AAAAAAAA8D/OK9MDb0rwP68QOq4ag/' ... '5xFDeX8z+urvcqw5/zP2qQawKBaPM/'),
#                     'dtype': 'f8'}}],
#     'layout': {'margin': {'l': 100, 'r': 20, 't': 110},
#                'showlegend': True,
#                'template': '...',
#                'title': {'text': 'Stock Price Data 2018 - 2020'},
#                'xaxis': {'linecolor': 'rgb(204,204,204)',
#                          'linewidth': 2,
#                          'showgrid': False,
#                          'showline': True,
#                          'showticklabels': True,
#                          'tickfont': {'color': 'rgb(82,82,82)', 'family': 'Arial', 'size': 12},
#                          'ticks': 'outside'},
#                'yaxis': {'automargin': False, 'showgrid': False, 'showline': False, 'zeroline': False}}
# })
