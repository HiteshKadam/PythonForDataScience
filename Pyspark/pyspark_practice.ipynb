# %% [markdown]
# # PySpark

# %%
import pyspark

# %%
import pandas as pd
pd.read_csv("test1.csv")
# Out:
#      Name  Age
# 0  Hitesh   26
# 1    Monu   30
# 2   Sunny   29

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Learn Spark").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/07/21 14:22:48 WARN Utils: Your hostname, tagtshen-H510M-S2, resolves to a loopback address: 127.0.1.1; using 158.144.55.107 instead (on interface enp2s0)
# 26/07/21 14:22:48 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# /home/tagtshen/PycharmProjects/PythonForDataScience/.venv/lib/python3.12/site-packages/pyspark/testing/utils.py:127: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
# 26/07/21 14:22:49 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://158.144.55.107:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Learn Spark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark = spark.read.csv("test1.csv", inferSchema=True, header=True)

# %%
df_pyspark
# Out:
# DataFrame[Name: string, Age: int]

# %%
type(df_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df_pyspark.head()
# Out:
# Row(Name='Hitesh', Age=26)

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: integer (nullable = true)

# %% [markdown]
# #### In this Video We will Cover
# - PySpark Dataframe
# - Reading The Dataset
# - Checking the Datatypes of the Column(Schema)
# - Selecting Columns And Indexing
# - Check Describe option similar to Pandas
# - Adding Columns
# - Dropping columns
# - Renaming Columns

# %%
df_pyspark.show()
# Out:
# +------+---+
# |  Name|Age|
# +------+---+
# |Hitesh| 26|
# |  Monu| 30|
# | Sunny| 29|
# +------+---+

# %%
df_pyspark.columns
# Out:
# ['Name', 'Age']

# %%
df_pyspark.select(["Name","Age"]).show()
# Out:
# +------+---+
# |  Name|Age|
# +------+---+
# |Hitesh| 26|
# |  Monu| 30|
# | Sunny| 29|
# +------+---+

# %%
df_pyspark["Name"]
# Out:
# Column<'Name'>

# %%
df_pyspark.describe().show()
# Out:
# +-------+------+------------------+
# |summary|  Name|               Age|
# +-------+------+------------------+
# |  count|     3|                 3|
# |   mean|  NULL|28.333333333333332|
# | stddev|  NULL|2.0816659994661326|
# |    min|Hitesh|                26|
# |    max| Sunny|                30|
# +-------+------+------------------+

# %%
df_pyspark.withColumn("Age After 2 years", df_pyspark["Age"] + 2).show()
# Out:
# +------+---+-----------------+
# |  Name|Age|Age After 2 years|
# +------+---+-----------------+
# |Hitesh| 26|               28|
# |  Monu| 30|               32|
# | Sunny| 29|               31|
# +------+---+-----------------+

# %%
df_pyspark.drop("Age After 2 years").show()
# Out:
# +------+---+
# |  Name|Age|
# +------+---+
# |Hitesh| 26|
# |  Monu| 30|
# | Sunny| 29|
# +------+---+

# %%
df_pyspark.withColumnRenamed("Age", "Age in 2026").show()
# Out:
# +------+-----------+
# |  Name|Age in 2026|
# +------+-----------+
# |Hitesh|         26|
# |  Monu|         30|
# | Sunny|         29|
# +------+-----------+
