# %% [markdown]
# #### Pyspark GroupBy & Aggregate Functions

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("MySparkApp").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/07/26 23:07:43 WARN Utils: Your hostname, Hiteshs-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 192.168.0.106 instead (on interface en0)
# 26/07/26 23:07:43 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# /Users/hiteshkadam/PycharmProjects/PythonForDataScience/.venv/lib/python3.13/site-packages/pyspark/testing/utils.py:127: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
# 26/07/26 23:07:53 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df = spark.read.csv("test3.csv", header=True, inferSchema=True)
df.show()
# Out:
# +---------+------------+------+
# |     Name| Departments|salary|
# +---------+------------+------+
# |    Krish|Data Science| 10000|
# |    Krish|         IOT|  5000|
# |   Mahesh|    Big Data|  4000|
# |    Krish|    Big Data|  4000|
# |   Mahesh|Data Science|  3000|
# |Sudhanshu|Data Science| 20000|
# |Sudhanshu|         IOT| 10000|
# |Sudhanshu|    Big Data|  5000|
# |    Sunny|Data Science| 10000|
# |    Sunny|    Big Data|  2000|
# +---------+------------+------+

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Departments: string (nullable = true)
#  |-- salary: integer (nullable = true)

# %% [markdown]
# ## Groupby

# %%
df.groupBy("Name").sum().show()
# Out:
# +---------+-----------+
# |     Name|sum(salary)|
# +---------+-----------+
# |Sudhanshu|      35000|
# |    Sunny|      12000|
# |    Krish|      19000|
# |   Mahesh|       7000|
# +---------+-----------+

# %%
### Groupby Department which gives max salary

df.groupBy("Departments").max("Salary").show()
# Out:
# +------------+-----------+
# | Departments|max(Salary)|
# +------------+-----------+
# |         IOT|      10000|
# |    Big Data|       5000|
# |Data Science|      20000|
# +------------+-----------+

# %%
df.groupBy("Departments").mean().show()
# Out:
# +------------+-----------+
# | Departments|avg(salary)|
# +------------+-----------+
# |         IOT|     7500.0|
# |    Big Data|     3750.0|
# |Data Science|    10750.0|
# +------------+-----------+

# %%
df.groupBy("Departments").count().show()
# Out:
# +------------+-----+
# | Departments|count|
# +------------+-----+
# |         IOT|    2|
# |    Big Data|    4|
# |Data Science|    4|
# +------------+-----+

# %%
df.agg({"Salary": "max"}).show()
# Out:
# +-----------+
# |max(Salary)|
# +-----------+
# |      20000|
# +-----------+
